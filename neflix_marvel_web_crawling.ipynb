# %%
import requests
from bs4 import BeautifulSoup
from trafilatura import fetch_url, extract
from trafilatura import fetch_url, extract

# %%
result = requests.get('https://search.naver.com/search.naver?where=news&query=%EB%84%B7%ED%94%8C%EB%A6%AD%EC%8A%A4%20%EB%A7%88%EB%B8%94&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds=2011.11.21&de=2024.11.21&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom20111121to20241121&is_sug_officeid=0&office_category=0&service_area=0', auth=('user', 'pass'))

soup = BeautifulSoup(result.text)
news_content = soup.find("div", {"class": "group_news"})
print(news_content)
# Out:
# <div class="group_news"> <ul class="list_news _infinite_list" data-img-mutation=""> <li class="bx" id="sp_nws1"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.hankookilbo.com/News/Read/A2024112011440002813?did=NA" href="#" onclick="tCR('a=nws*e.kep&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*e.kepoff&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u=javascript" data-cr-on="a=nws*e.kepon&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*e.kephome&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class="info_group"> <a class="info press" href="http://www.hankookilbo.com/" onclick="return goOtherCR(this, 'a=nws*e.prof&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;g=469.0000834350&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F469%2F2023%2F02%2F09%2Flogo_469_18_20230209131305.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" height="24" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="24"/></span>한국일보</a><span class="info"><i class="spnew ico_paper"></i>23면 1단</span><span class="info">22시간 전</span><a class="info" href="https://n.news.naver.com/mnews/article/469/0000834350?sid=103" onclick="return goOtherCR(this, 'a=nws*e.nav&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </div></div><div class="news_contents"> <a class="dsc_thumb" href="https://www.hankookilbo.com/News/Read/A2024112011440002813?did=NA" onclick="return goOtherCR(this, 'a=nws*e.img&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;g=469.0000834350&amp;u='+urlencode(this.href));" target="_blank"><img alt="넷플릭스 ‘오징어 게임" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F469%2F2024%2F11%2F20%2F834350.jpg&amp;type=f200_200&amp;expire=2&amp;refresh=true" height="104" onerror="this.parentNode.style.display='none';" src="..." width="104"/></a> <a class="news_tit" href="https://www.hankookilbo.com/News/Read/A2024112011440002813?did=NA" onclick="return goOtherCR(this, 'a=nws*e.tit&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;g=469.0000834350&amp;u='+urlencode(this.href));" target="_blank" title="넷플릭스 '오징어 게임2'냐,  디즈니 '조명가게'냐...연말 OTT 경쟁 벌써 뜨겁다"><mark>넷플릭스</mark> '오징어 게임2'냐, 디즈니 '조명가게'냐...연말 OTT 경쟁 벌써...</a> <div class="news_dsc"> <div class="dsc_wrap"> <a class="api_txt_lines dsc_txt_wrap" href="https://www.hankookilbo.com/News/Read/A2024112011440002813?did=NA" onclick="return goOtherCR(this, 'a=nws*e.body&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;g=469.0000834350&amp;u='+urlencode(this.href));" target="_blank">디즈니와 <mark>마블</mark>, 21세기폭스, 픽사 등 디즈니 산하 콘텐츠 회사들이 올해 말과 내년에 전 세계에 공개하는 영화와 오리지널 콘텐츠를 발표한 20일 쇼케이스... 디즈니플러스와 <mark>넷플릭스</mark>가 최대 기대작을 모두 연말에 공개하면서 경쟁도 예상된다. <mark>넷플릭스</mark>는 '오징어 게임2'를 다음 달 26일 공개한다. "'쇼군' '무빙...</a> </div></div></div></div></div></li> <li class="bx" id="sp_nws2"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://ent.sbs.co.kr/news/article.do?article_id=E10010294510&amp;plink=ORI&amp;cooper=NAVER" href="#" onclick="tCR('a=nws*e.kep&amp;r=2&amp;i=8812805F_00000000 ...

# %%
some_tag = news_content.find("ul", {"class" : "list_news"}).extract()

# %%
some_tag
# Out:
# <ul class="list_news _infinite_list" data-img-mutation=""> <li class="bx" id="sp_nws1"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.hankookilbo.com/News/Read/A2024112011440002813?did=NA" href="#" onclick="tCR('a=nws*e.kep&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws*e.kepoff&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u=javascript" data-cr-on="a=nws*e.kepon&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws*e.kephome&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class="info_group"> <a class="info press" href="http://www.hankookilbo.com/" onclick="return goOtherCR(this, 'a=nws*e.prof&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;g=469.0000834350&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F469%2F2023%2F02%2F09%2Flogo_469_18_20230209131305.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" height="24" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="24"/></span>한국일보</a><span class="info"><i class="spnew ico_paper"></i>23면 1단</span><span class="info">22시간 전</span><a class="info" href="https://n.news.naver.com/mnews/article/469/0000834350?sid=103" onclick="return goOtherCR(this, 'a=nws*e.nav&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </div></div><div class="news_contents"> <a class="dsc_thumb" href="https://www.hankookilbo.com/News/Read/A2024112011440002813?did=NA" onclick="return goOtherCR(this, 'a=nws*e.img&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;g=469.0000834350&amp;u='+urlencode(this.href));" target="_blank"><img alt="넷플릭스 ‘오징어 게임" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F469%2F2024%2F11%2F20%2F834350.jpg&amp;type=f200_200&amp;expire=2&amp;refresh=true" height="104" onerror="this.parentNode.style.display='none';" src="..." width="104"/></a> <a class="news_tit" href="https://www.hankookilbo.com/News/Read/A2024112011440002813?did=NA" onclick="return goOtherCR(this, 'a=nws*e.tit&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;g=469.0000834350&amp;u='+urlencode(this.href));" target="_blank" title="넷플릭스 '오징어 게임2'냐,  디즈니 '조명가게'냐...연말 OTT 경쟁 벌써 뜨겁다"><mark>넷플릭스</mark> '오징어 게임2'냐, 디즈니 '조명가게'냐...연말 OTT 경쟁 벌써...</a> <div class="news_dsc"> <div class="dsc_wrap"> <a class="api_txt_lines dsc_txt_wrap" href="https://www.hankookilbo.com/News/Read/A2024112011440002813?did=NA" onclick="return goOtherCR(this, 'a=nws*e.body&amp;r=1&amp;i=88156f75_000000000000000000834350&amp;g=469.0000834350&amp;u='+urlencode(this.href));" target="_blank">디즈니와 <mark>마블</mark>, 21세기폭스, 픽사 등 디즈니 산하 콘텐츠 회사들이 올해 말과 내년에 전 세계에 공개하는 영화와 오리지널 콘텐츠를 발표한 20일 쇼케이스... 디즈니플러스와 <mark>넷플릭스</mark>가 최대 기대작을 모두 연말에 공개하면서 경쟁도 예상된다. <mark>넷플릭스</mark>는 '오징어 게임2'를 다음 달 26일 공개한다. "'쇼군' '무빙...</a> </div></div></div></div></div></li> <li class="bx" id="sp_nws2"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://ent.sbs.co.kr/news/article.do?article_id=E10010294510&amp;plink=ORI&amp;cooper=NAVER" href="#" onclick="tCR('a=nws*e.kep&amp;r=2&amp;i=8812805F_000000000000000000309483&amp;u=ja ...

# %% [markdown]
# JSON데이터로 뉴스 기사 가져오기

# %%
url = fetch_url("https://search.naver.com/search.naver?where=news&query=%EB%84%B7%ED%94%8C%EB%A6%AD%EC%8A%A4%20%EB%A7%88%EB%B8%94&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds=2011.11.21&de=2024.11.21&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Ar%2Cp%3Afrom20111121to20241121&is_sug_officeid=0&office_category=0&service_area=0")

# %%
print(extract(url, output_format='json', with_metadata=True, deduplicate=True))
# Out:
# {"title": "연관 검색어", "author": null, "hostname": null, "date": "2023-06-15", "fingerprint": "a6c788f199eb75cb", "id": null, "license": null, "comments": "", "raw_text": "넷플릭스 마블 뉴스검색 결과    서비스 영역       기자명         \"뭘 좋아할지 몰라 다 준비했어\" 마블, 2025년 디즈니+ 라인업 공개  디지털투데이3주 전  \"뭘 좋아할지 몰라 다 준비했어\" 마블, 2025년 디즈니+ 라인업 공개        콘진원, '2024 콘텐츠 인사이트' 개최  뉴스워커1주 전  콘진원, '2024 콘텐츠 인사이트' 개최…콘텐츠 전문가 강연 진행  뉴스핌1주 전  `흑백요리사` 제작진이 전하는 콘텐츠의 진화…콘진원, 2024 콘텐츠 인사...  디지털타임스1주 전네이버뉴스  콘진원, '2024 콘텐츠 인사이트' 개최", "text": "넷플릭스 마블 뉴스검색 결과\n- 서비스 영역\n- 기자명\n-\n-\n- \"뭘 좋아할지 몰라 다 준비했어\" 마블, 2025년 디즈니+ 라인업 공개 디지털투데이3주 전\n- \"뭘 좋아할지 몰라 다 준비했어\" 마블, 2025년 디즈니+ 라인업 공개\n-\n- 콘진원, '2024 콘텐츠 인사이트' 개최 뉴스워커1주 전\n- 콘진원, '2024 콘텐츠 인사이트' 개최…콘텐츠 전문가 강연 진행 뉴스핌1주 전\n- `흑백요리사` 제작진이 전하는 콘텐츠의 진화…콘진원, 2024 콘텐츠 인사... 디지털타임스1주 전네이버뉴스\n- 콘진원, '2024 콘텐츠 인사이트' 개최", "language": null, "image": "https://ssl.pstatic.net/sstatic/search/common/og_v3.png", "pagetype": null, "filedate": "2024-11-21", "source": null, "source-hostname": null, "excerpt": "'넷플릭스 마블'의 네이버 뉴스검색 결과입니다.", "categories": "", "tags": ""}

# %%
# 1. 넷플릭스 마블 영화
# 2. 넷플릭스 dc 코믹스 영화
# 3. 넷플릭스 흥행 영화

# %%
# 수집된 기사에서 가져온 contents를 리스트에 저장
from trafilatura import fetch_url, extract
import json
import requests
from bs4 import BeautifulSoup
from trafilatura import fetch_url, extract

cur_page = 1
def get_contents(cur_page):
    save_contents = []
    
    while(True):
        try:
            url = f'https://s.search.naver.com/p/newssearch/search.naver?cluster_rank=16&de=2024.11.21&ds=2021.11.21&eid=&field=0&force_original=&is_dts=0&is_sug_officeid=0&mynews=0&news_office_checked=&nlu_query=&nqx_theme=%7B%22theme%22%3A%7B%22main%22%3A%7B%22name%22%3A%22movie%22%2C%22score%22%3A%220.876183%22%7D%7D%7D&nso=%26nso%3Dso%3Ar%2Cp%3Afrom20211121to20241121%2Ca%3Aall&nx_and_query=&nx_search_hlquery=&nx_search_query=&nx_sub_query=&office_category=0&office_section_code=0&office_type=0&pd=3&photo=0&query=%EB%84%B7%ED%94%8C%EB%A6%AD%EC%8A%A4+%EC%9D%B8%EA%B8%B0+%EC%98%81%ED%99%94&query_original=&service_area=0&sort=0&spq=0&start={cur_page}&where=news_tab_api&nso=so:r,p:from20211121to20241121,a:all&'

            result = requests.get(url)
            try:
                result = result.json()
            except json.JSONDecodeError as e:
                print(f'json 디코딩 에러')
                break
            contents = result["contents"]
            content_url = result["nextUrl"]
            
            if not contents:
                break
            if not content_url:
                break

            for content in contents:
                contentt = get_content(content)
                if contentt:
                    save_contents.append(contentt)
            
            cur_page += 10
            print(cur_page)
        except Exception as e:
            print(f"에러 발생")
            break
        
    return save_contents

def get_content(content):
    content_soup = BeautifulSoup(content, 'html.parser')
    news_title = content_soup.find("a", {"class": "news_tit"})
    if news_title and news_title['title']:
        return news_title['title']
    return None

save_contents = get_contents(cur_page)
print(len(save_contents))
# Out:
# 11
# 21
# 31
# 41
# 51
# 61
# 71
# 81
# 91
# 101
# 111
# 121
# 131
# 141
# 151
# 161
# 171
# 181
# 191
# 201
# 211
# 221
# 231
# 241
# 251
# 261
# 271
# 281
# 291
# 301
# json 디코딩 에러
# 300

# %%
import pandas as pd

print("총 개수 :", len(save_contents))
df = pd.DataFrame(save_contents, columns=['content'])
df.to_csv('./crawling_datas/news_three')
# Out:
# 총 개수 : 300

# %%
from kiwipiepy import Kiwi
from collections import Counter

input_wc = ' '.join(df['content'].astype(str))

kiwi = Kiwi()
kiwi.analyze(input_wc)
# Out:
# [([Token(form='김수현', tag='NNP', start=0, len=3),
#    Token(form='∙', tag='SW', start=3, len=1),
#    Token(form='김혜수', tag='NNP', start=4, len=3),
#    Token(form='∙', tag='SW', start=7, len=1),
#    Token(form='강동원', tag='NNP', start=8, len=3),
#    Token(form='∙', tag='SW', start=11, len=1),
#    Token(form='전지현', tag='NNP', start=12, len=3),
#    Token(form='…', tag='SE', start=15, len=1),
#    Token(form='디즈니', tag='NNG', start=16, len=3),
#    Token(form='+', tag='SW', start=19, len=1),
#    Token(form=',', tag='SP', start=20, len=1),
#    Token(form='넷플릭스', tag='NNP', start=22, len=4),
#    Token(form='자리', tag='NNG', start=27, len=2),
#    Token(form='넘보', tag='VV', start=30, len=2),
#    Token(form='는', tag='ETM', start=32, len=1),
#    Token(form='호화', tag='NNG', start=34, len=2),
#    Token(form='라인업', tag='NNG', start=37, len=3),
#    Token(form='(', tag='SSO', start=40, len=1),
#    Token(form='종합', tag='NNG', start=41, len=2),
#    Token(form=')', tag='SSC', start=43, len=1),
#    Token(form='차갑', tag='VA-I', start=45, len=3),
#    Token(form='은', tag='ETM', start=47, len=1),
#    Token(form='날씨', tag='NNG', start=49, len=2),
#    Token(form='속', tag='NNG', start=52, len=1),
#    Token(form="'", tag='SSO', start=54, len=1),
#    Token(form='집', tag='NNG', start=55, len=1),
#    Token(form='콕', tag='NNG', start=56, len=1),
#    Token(form="'", tag='SSC', start=57, len=1),
#    Token(form='책임지', tag='VV', start=59, len=3),
#    Token(form='ᆯ', tag='ETM', start=61, len=1),
#    Token(form='넷플릭스', tag='NNP', start=63, len=4),
#    Token(form='금주', tag='NNG', start=68, len=2),
#    Token(form='신작', tag='NNG', start=71, len=2),
#    Token(form='넷플릭스', tag='NNP', start=74, len=4),
#    Token(form='책임자', tag='NNG', start=79, len=3),
#    Token(form='"', tag='SSO', start=83, len=1),
#    Token(form='오징어', tag='NNG', start=84, len=3),
#    Token(form='게임', tag='NNG', start=87, len=2),
#    Token(form='2', tag='SN', start=89, len=1),
#    Token(form=',', tag='SP', start=90, len=1),
#    Token(form='놀랍', tag='VA-I', start=92, len=3),
#    Token(form='은', tag='ETM', start=94, len=1),
#    Token(form='반전', tag='NNG', start=96, len=2),
#    Token(form='곳곳', tag='NNG', start=99, len=2),
#    Token(form='에', tag='JKB', start=101, len=1),
#    Token(form='…', tag='SE', start=102, len=1),
#    Token(form='성공', tag='NNG', start=103, len=2),
#    Token(form='확신', tag='NNG', start=106, len=2),
#    Token(form='"', tag='SSC', start=108, len=1),
#    Token(form='넷플릭스', tag='NNP', start=110, len=4),
#    Token(form=',', tag='SP', start=114, len=1),
#    Token(form='K', tag='SL', start=116, len=1),
#    Token(form='콘텐츠', tag='NNG', start=117, len=3),
#    Token(form='파상', tag='NNG', start=121, len=2),
#    Token(form='공세', tag='NNG', start=123, len=2),
#    Token(form='...', tag='SF', start=125, len=3),
#    Token(form='토종', tag='NNG', start=128, len=2),
#    Token(form='OTT', tag='SL', start=131, len=3),
#    Token(form='대', tag='NNG', start=135, len=1),
#    Token(form='안', tag='MAG', start=136, len=1),
#    Token(form='있', tag='VV', start=138, len=1),
#    Token(form='나', tag='EC', start=139, len=1),
#    Token(form='"', tag='SSO', start=141, len=1),
#    Token(form='전', tag='MM', start=142, len=1),
#    Token(form='세계', tag='NNG', start=144, len=2),
#    Token(form='넷플릭스', tag='NNP', start=147, len=4),
#    Token(form='가입자', tag='NNG', start=152, len=3),
#    Token(form='80', tag='SN', start=156, len=2),
#    Token(form='%', tag='SW', start=158, len=1),
#    Token(form='가', tag='JKS', start=159, len=1),
#    Token(form='K', tag='SL', start=161, len=1),
#    Token(form='콘텐츠', tag='NNG', start=162, len=3),
#    Token(form='보', tag='VV', start=166, len=1),
#    Token(form='어', tag='EF', start=166, len=1),
#    Token(form='...', tag='SF', start=167, len=3),
#    Token(form='오겜2', tag='NNG', start=171, len=3),
#    Token(form=',', tag='SP', start=174, len=1),
#    Token(form='기대', tag='NNG', start=176, len=2),
#    Token(form='부응', tag='NNG', start=179, len=2),
#    Token(form='하', tag='XSV', start=181, len=1),
#    Token(form='ᆯ', tag='ETM', start=181, len=1),
#    Token(form='것', tag='NNB', start=183, len=1),
#    Token(form='"', tag='SSC', start=184, len=1),
#    Token(form='영화', tag='NNG', start=186, len=2),
#    Token(form='는', tag='JX', start=188, len=1),
#    Token(form='나', tag='NP', start=190, len=1),
#    Token(form='의', tag='JKG', start=190, len=1),
#    Token(form='영혼', tag='NNG', start=192, len=2),
#    Token(form='…', tag='SE', start=194, len=1),
#    Token(form='아시안', tag='NNG', start=195, len=3),
#    Token(form='목소리', tag='NNG', start=199, len=3),
#    Token(form='담', tag='VV', start=203, len=1),
#    Token(form='고', tag='EC', start=204, len=1),
#    Token(form='싶', tag='VX', start=206, len=1),
#    Token(form='다', tag='EC', start=207, len=1),
#    Token(form='넷플릭스', tag='NNP', start=209, len=4),
#    Token(form='공개', tag='NNG', start=214, len=2),
#    Token(form='2', tag='SN', start=217, len=1),
#    Token(form='주', tag='NNB', start=218, len=1),
#    Token(form='만', tag='NNB', start=220, len=1),
#    Token(form='에', tag='JKB', start=221, len=1),
#    Token(form='…', tag='SE', start=222, len=1),
#    Token(form='해외', tag='NNG', start=224, len=2),
#    Token(form='에서', tag='JKB', start=226, len=2),
#    Token(form='반응', tag='NNG', start=229, len=2),
#    Token(form='터지', tag='VV', start=232, len=2),
#    Token(form='었', tag='EP', start=233, len=1),
#    Token(form='다는', tag='ETM', start=234, len=2),
#    Token(form='한국', tag='NNP', start=237, len=2),
#    Token(form='드라마', tag='NNG', start=240, len=3),
#    Token(form='1000', tag='SN', start=244, len=4),
#    Token(form='억', tag='NR', start=248, len=1),
#    Token(form="'", tag='SSO', start=250, len=1),
#    Token(form='오징어', tag='NNG', start=251, len=3),
#    Token(form='게임', tag='NNG', start=254, len=2),
#    Token(form='2', tag='SN', start=256, len=1),
#    Token(form="'", tag='SSC', start=257, len=1),
#    Token(form='주의보', tag='NNG', start=259, len=3),
#    Token(form='…', tag='SE', start=262, len=1),
#    Token(form='극장가', tag='NNG', start=263, len=3),
#    Token(form='한국', tag='NNP', start=267, len=2),
#    Token(form='영화', tag='NNG', start=269, len=2),
#    Token(form='눈치', tag='NNG', start=272, len=2),
#    Token(form='싸움', tag='NNG', start=274, len=2),
#    Token(form="'", tag='SSC', start=277, len=1),
#    Token(form='치열', tag='NNG', start=278, len=2),
#    Token(form="'", tag='SSO', start=280, len=1),
#    Token(form='넷플릭스', tag='NNP', start=282, len=4),
#    Token(form="'", tag='SSC', start=287, len=1),
#    Token(form='오징어', tag='NNG', start=288, len=3),
#    Token(form='게임', tag='NNG', start=292, len=2),
#    Token(form='2', tag='SN', start=294, len=1),
#    Token(form="'", tag='SSC', start=295, len=1),
#    Token(form='이', tag='VCP', start=296, len=0),
#    Token(form='냐', tag='EC', start=296, len=1),
#    Token(form=',', tag='SP', start=297, len=1),
#    Token(form='디즈니', tag='NNP', start=299, len=3),
#    Token(form="'", tag='SSO', start=303, len=1),
#    Token(form='조명', tag='NNG', start=304, len=2),
#    Token(form='가게', tag='NNG', start=306, len=2),
#    Token(form="'", tag='SSC', start=308, len=1),
#    Token(form='이', tag='VCP', start=309, len=0),
#    Token(form='냐', tag='EC', start=309, len=1),
#    Token(form='...', tag='SF', start=310, len=3),
#    Token(form='연말', tag='NNG', start=313, len=2),
#    Token(form='OTT', tag='SL', start=316, len=3),
#    Token(form='경쟁', tag='NNG', start=320, len=2),
#    Token(form='벌써', tag='MAG', start=323, len=2),
#    Token(form='뜨겁', tag='VA-I', start=326, len=2),
#    Token(form='다', tag='EF', start=328, len=1),
#    Token(form='영화', tag='NNG', start=330, len=2),
#    Token(form='·', tag='SP', start=332, len=1),
#    Token(form='예능', tag='NNG', start=333, len=2),
#    Token(form='에', tag='JKB', start=335, len=1),
#    Token(form='‘', tag='SSO', start=337, len=1),
#    Token(form='스포츠', tag='NNG', start=338, len=3),
#    Token(form='’', tag='SSC', start=341, len=1),
#    Token(form='바람', tag='NNG', start=343, len=2),
#    Token(form='이', tag='JKS', start=345, len=1),
#    Token(form='불', tag='VV', start=347, len=1),
#    Token(form='ᆫ다', tag='EF', start=347, len=2),
#    Token(form='넷플릭스', tag='NNP', start=350, len=4),
#    Token(form='1', tag='SN', start=355, len=1),
#    Token(form='위', tag='NNB', start=356, len=1),
#    Token(form='압도', tag='NNG', start=358, len=2),
#    Token(form='적', tag='XSN', start=360, len=1),
#    Token(form='독주', tag='NNG', start=362, len=2),
#    Token(form='중', tag='NNB', start=365, len=1),
#    Token(form='…', tag='SE', start=366, len=1),
#    Token(form='공개', tag='NNG', start=367, len=2),
#    Token(form='후', tag='NNG', start=370, len=1),
#    Token(form='OTT', tag='SL', start=372, len=3),
#    Token(form='서', tag='JKB', start=375, len=1),
#    Token(form='난리', tag='NNG', start=377, len=2),
#    Token(form='나', tag='VV', start=380, len=1),
#    Token(form='ᆫ', tag='ETM', start=380, len=1),
#    Token(form="'", tag='SSO', start=382, len=1),
#    Token(form='한국', tag='NNP', start=383, len=2),
#    Token(form='영화', tag='NNG', start=386, len=2),
#    Token(form="'", tag='SSC', start=388, len=1),
#    Token(form='1000', tag='SN', start=390, len=4),
#    Token(form='억', tag='NR', start=394, len=1),
#    Token(form="'", tag='SSO', start=396, len=1),
#    Token(form='오징어', tag='NNG', start=397, len=3),
#    Token(form='게임', tag='NNG', start=400, len=2),
#    Token(form='2', tag='SN', start=402, len=1),
#    Token(form="'", tag='SSC', start=403, len=1),
#    Token(form='주의보', tag='NNG', start=405, len=3),
#    Token(form='…', tag='SE', start=408, len=1),
#    Token(form='극장가', tag='NNG', start=409, len=3),
#    Token(form='한국', tag='NNP', start=413, len=2),
#    Token(form='영화', tag='NNG', start=415, len=2),
#    Token(form='눈치', tag='NNG', start=418, len=2),
#    Token(form='싸움', tag='NNG', start=420, len=2),
#    Token(form="'", tag='SSC', start=423, len=1),
#    Token(form='치열', tag='NNG', start=424, len=2),
#    Token(form="'", tag='SSO', start=426, len=1),
#    Token(form='디즈니', tag='NNP', start=428, len=3),
#    Token(form='+', tag='SW', start=431, len=1),
#    Token(form=',', tag='SP', start=432, len=1),
#    Token(form='2025', tag='SN', start=434, len=4),
#    Token(form='년', tag='NNB', start=438, len=1),
#    Token(form='판', tag='NNG', start=440, len=1),
#    Token(form='도', tag='JX', start=441, len=1),
#    Token(form='뒤흔들', tag='VV', start=443, len=3),
#    Token(form='나', tag='EF', start=446, len=1),
#    Token(form='?', tag='SF', start=447, len=1),
#    Token(form='…', tag='SE', start=448, len=1),
#    Token(form='넷플릭스', tag='NNP', start=449, len=4),
#    Token(form='위협', tag='NNG', start=454, len=2),
#    Token(form='하', tag='XSV', start=456, len=1),
#    Token(form='ᆯ', tag='ETM', start=456, len=1),
#    Token(form='글로벌', tag='NNG', start=458, len=3),
#    Token(form='라인업', tag='NNG', start=462, len=3),
#    Token(form='11', tag='SN', start=466, len=2),
#    Token(form="'", tag='SSC', start=469, len=1),
#    Token(form='벗', tag='VV-R', start=470, len=1),
#    Token(form='는', tag='ETM', start=471, len=1),
#    Token(form='영화', tag='NNG', start=473, len=2),
#    Token(form="'", tag='SSC', start=475, len=1),
#    Token(form='?', tag='SF', start=476, len=1),
#    Token(form='NO', tag='SL', start=478, len=2),
#    Token(form='!', tag='SF', start=480, len=1),
#    Token(form="'", tag='SSO', start=482, len=1),
#    Token(form='히든 페이스', tag='NNP', start=483, len=5),
#    Token(form="'", tag='SSC', start=488, len=1),
#    Token(form='로', tag='JKB', start=489, len=1),
#    Token(form='다시', tag='MAG', start=491, len=2),
#    Token(form='보', tag='VV', start=494, len=1),
#    Token(form='는', tag='ETM', start=495, len=1),
#    Token(form='관능미', tag='NNG', start=497, len=3),
#    Token(form='영화', tag='NNG', start=501, len=2),
#    Token(form='BEST', tag='SL', start=504, len=4),
#    Token(form='5', tag='SN', start=509, len=1),
#    Token(form='[', tag='SSO', start=511, len=1),
#    Token(form='세종로', tag='NNP', start=512, len=3),
#    Token(form='의', tag='JKG', start=515, len=1),
#    Token(form='아침', tag='NNG', start=517, len=2),
#    Token(form=']', tag='SSC', start=519, len=1),
#    Token(form='갈림길', tag='NNG', start=521, len=3),
#    Token(form='에', tag='JKB', start=524, len=1),
#    Token(form='서', tag='VV', start=526, len=1),
#    Token(form='ᆫ', tag='ETM', start=526, len=1),
#    Token(form='한국', tag='NNP', start=528, len=2),
#    Token(form='영화', tag='NNG', start=531, len=2),
#    Token(form='영화', tag='NNG', start=534, len=2),
#    Token(form='ㆍ', tag='SW', start=536, len=1),
#    Token(form='게임', tag='NNG', start=537, len=2),
#    Token(form='으로', tag='JKB', start=539, len=2),
#    Token(form='…', tag='SE', start=541, len=1),
#    Token(form='K', tag='SL', start=542, len=1),
#    Token(form='-', tag='SO', start=543, len=1),
#    Token(form='웹툰', tag='NNP', start=544, len=2),
#    Token(form=',', tag='SP', start=546, len=1),
#    Token(form='IP', tag='SL', start=548, len=2),
#    Token(form='2', tag='SN', start=551, len=1),
#    Token(form='차', tag='NNB', start=552, len=1),
#    Token(form='사업', tag='NNG', start=554, len=2),
#    Token(form="'", tag='SSO', start=557, len=1),
#    Token(form='확장', tag='NNG', start=558, len=2),
#    Token(form='일', tag='NNG', start=560, len=1),
#    Token(form='로', tag='JKB', start=561, len=1),
#    Token(form="'", tag='SSC', start=562, len=1),
#    Token(form='“', tag='SSO', start=564, len=1),
#    Token(form='수위', tag='NNG', start=565, len=2),
#    Token(form='더', tag='MAG', start=568, len=1),
#    Token(form='높아지', tag='VV', start=570, len=3),
#    Token(form='었', tag='EP', start=572, len=1),
#    Token(form='다', tag='EF', start=573, len=1),
#    Token(form='”', tag='SSC', start=574, len=1),
#    Token(form='13', tag='SN', start=576, len=2),
#    Token(form='년', tag='NNB', start=578, len=1),
#    Token(form='만', tag='NNB', start=580, len=1),
#    Token(form='에', tag='JKB', start=581, len=1),
#    Token(form='한국', tag='NNP', start=583, len=2),
#    Token(form='영화', tag='NNG', start=586, len=2),
#    Token(form='로', tag='JKB', start=588, len=1),
#    Token(form='재', tag='XPN', start=590, len=1),
#    Token(form='탄생', tag='NNG', start=591, len=2),
#    Token(form='하', tag='XSV', start=593, len=1),
#    Token(form='ᆫ', tag='ETM', start=593, len=1),
#    Token(form='19', tag='SN', start=595, len=2),
#    Token(form='금', tag='NNG', start=597, len=1),
#    Token(form='영화', tag='NNG', start=599, len=2),
#    Token(form=',', tag='SP', start=601, len=1),
#    Token(form='넷플릭스', tag='NNP', start=603, len=4),
#    Token(form='서', tag='JKB', start=607, len=1),
#    Token(form='역주행', tag='NNG', start=609, len=3),
#    Token(form='중', tag='NNB', start=613, len=1),
#    Token(form='넷플릭스', tag='NNP', start=615, len=4),
#    Token(form='"', tag='SSO', start=620, len=1),
#    Token(form='오징어', tag='NNG', start=621, len=3),
#    Token(form='게임', tag='NNG', start=624, len=2),
#    Token(form='2', tag='SN', start=626, len=1),
#    Token(form=',', tag='SP', start=627, len=1),
#    Token(form='곳곳', tag='NNG', start=629, len=2),
#    Token(form='에', tag='JKB', start=631, len=1),
#    Token(form='놀랍', tag='VA-I', start=633, len=3),
#    Token(form='은', tag='ETM', start=635, len=1),
#    Token(form='반전', tag='NNG', start=637, len=2),
#    Token(form='…', tag='SE', start=639, len=1),
#    Token(form='성공', tag='NNG', start=640, len=2),
#    Token(form='확신', tag='NNG', start=643, len=2),
#    Token(form='"', tag='SSC', start=645, len=1),
#    Token(form='〈', tag='SSO', start=647, len=1),
#    Token(form='흑백', tag='NNG', start=648, len=2),
#    Token(form='요리사', tag='NNG', start=650, len=3),
#    Token(form='〉', tag='SSC', start=653, len=1),
#    Token(form='흥행', tag='NNG', start=655, len=2),
#    Token(form='과', tag='JC', start=657, len=1),
#    Token(form='넷플릭스', tag='NNP', start=659, len=4),
#    Token(form='실적', tag='NNG', start=664, len=2),
#    Token(form='은', tag='JX', start=666, len=1),
#    Token(form='별개', tag='NNG', start=668, len=2),
#    Token(form='이', tag='VCP', start=670, len=0),
#    Token(form='라고요', tag='EF', start=670, len=3),
#    Token(form='한강', tag='NNP', start=674, len=2),
#    Token(form='이', tag='JKS', start=676, len=1),
#    Token(form='노벨', tag='NNP', start=678, len=2),
#    Token(form='문학상', tag='NNG', start=680, len=3),
#    Token(form='수상', tag='NNG', start=684, len=2),
#    Token(form='하', tag='XSV', start=686, len=1),
#    Token(form='기', tag='ETN', start=687, len=1),
#    Token(form='까지', tag='JX', start=688, len=2),
#    Token(form='|', tag='SW', start=691, len=1),
#    Token(form='韓日', tag='SH', start=693, len=2),
#    Token(form=',', tag='SP', start=695, len=1),
#    Token(form='영화', tag='NNG', start=697, len=2),
#    Token(form='로', tag='JKB', start=699, len=1),
#    Token(form='시작', tag='NNG', start=701, len=2),
#    Token(form='하', tag='XSV', start=703, len=1),
#    Token(form='어', tag='EC', start=703, len=1),
#    Token(form='노벨', tag='NNP', start=705, len=2),
#    Token(form='문학상', tag='NNG', start=707, len=3),
#    Token(form='까지', tag='JX', start=710, len=2),
#    Token(form='닮은꼴', tag='NNG', start=713, len=3),
#    Token(form="'", tag='SSO', start=717, len=1),
#    Token(form='오징어', tag='NNG', start=718, len=3),
#    Token(form='게임', tag='NNG', start=722, len=2),
#    Token(form='2', tag='SN', start=724, len=1),
#    Token(form="'", tag='SSC', start=725, len=1),
#    Token(form='韓', tag='SH', start=727, len=1),
#    Token(form='넷플릭스', tag='NNP', start=729, len=4),
#    Token(form='시즌', tag='NNG', start=734, len=2),
#    Token(form='2', tag='SN', start=736, len=1),
#    Token(form='부진', tag='NNG', start=738, len=2),
#    Token(form='끊', tag='VV', start=741, len=1),
#    Token(form='어', tag='EC', start=742, len=1),
#    Token(form='내', tag='VX', start=743, len=1),
#    Token(form='ᆯ까', tag='EF', start=743, len=2),
#    Token(form='[', tag='SSO', start=746, len=1),
#    Token(form='TD', tag='SL', start=747, len=2),
#    Token(form='현장', tag='NNG', start=749, len=2),
#    Token(form='종합', tag='NNG', start=752, len=2),
#    Token(form=']', tag='SSC', start=754, len=1),
#    Token(form='배구', tag='NNG', start=756, len=2),
#    Token(form='영화', tag='NNG', start=759, len=2),
#    Token(form=',', tag='SP', start=761, len=1),
#    Token(form='축구', tag='NNG', start=763, len=2),
#    Token(form='·', tag='SP', start=765, len=1),
#    Token(form='럭비', tag='NNG', start=766, len=2),
#    Token(form='예능', tag='NNG', start=769, len=2),
#    Token(form='…', tag='SE', start=771, len=1),
#    Token(form='스포츠', tag='NNG', start=773, len=3),
#    Token(form='물', tag='NNG', start=776, len=1),
#    Token(form='이', tag='JKS', start=777, len=1),
#    Token(form='뜨', tag='VV', start=779, len=1),
#    Token(form='ᆫ다', tag='EF', start=779, len=2),
#    Token(form='이정재', tag='NNP', start=782, len=3),
#    Token(form='·', tag='SP', start=785, len=1),
#    Token(form='현빈', tag='NNP', start=786, len=2),
#    Token(form=',', tag='SP', start=788, len=1),
#    Token(form='크리스마스', tag='NNG', start=790, len=5),
#    Token(form='맞불', tag='NNG', start=796, len=2),
#    Token(form='…', tag='SE', start=798, len=1),
#    Token(form='집', tag='NNG', start=799, len=1),
#    Token(form='vs', tag='SL', start=800, len=2),
#    Token(form='영화관', tag='NNG', start=802, len=3),
#    Token(form='어디', tag='NP', start=806, len=2),
#    Token(form='로', tag='JKB', start=808, len=1),
#    Token(form='가', tag='VV', start=810, len=1),
#    Token(form='ᆯ까', tag='EC', start=810, len=2),
#    Token(form='[', tag='SSO', start=813, len=1),
#    Token(form='엑', tag='NNG', start=814, len=1),
#    Token(form="'", tag='SSC', start=815, len=1),
#    Token(form='s', tag='SL', start=816, len=1),
#    Token(form='이슈', tag='NNG', start=818, len=2),
#    Token(form=']', tag='SSC', start=820, len=1),
#    Token(form='김새론', tag='NNP', start=822, len=3),
#    Token(form=',', tag='SP', start=825, len=1),
#    Token(form='영화', tag='NNG', start=827, len=2),
#    Token(form='로', tag='JKB', start=829, len=1),
#    Token(form='복귀', tag='NNG', start=831, len=2),
#    Token(form='재', tag='XPN', start=834, len=1),
#    Token(form='도전', tag='NNG', start=835, len=2),
#    Token(form='..', tag='SF', start=837, len=2),
#    Token(form='음주운전', tag='NNP', start=839, len=4),
#    Token(form='→', tag='SW', start=843, len=1),
#    Token(form='셀프', tag='NNG', start=844, len=2),
#    Token(form='열애', tag='NNG', start=847, len=2),
#    Token(form='설', tag='NNB', start=849, len=1),
#    Token(form='극복', tag='NNG', start=851, len=2),
#    Token(form='하', tag='XSV', start=853, len=1),
#    Token(form='ᆯ까', tag='EC', start=853, len=2),
#    Token(form='[', tag='SSO', start=856, len=1),
#    Token(form='스타', tag='NNG', start=857, len=2),
#    Token(form='이슈', tag='NNG', start=859, len=2),
#    Token(form=']', tag='SSC', start=861, len=1),
#    Token(form='김새론', tag='NNP', start=863, len=3),
#    Token(form='복귀', tag='NNG', start=867, len=2),
#    Token(form='작', tag='NNG', start=869, len=1),
#    Token(form=',', tag='SP', start=870, len=1),
#    Token(form='남', tag='NNG', start=872, len=1),
#    Token(form='주', tag='VV', start=873, len=1),
#    Token(form='는', tag='ETM', start=874, len=1),
#    Token(form="'", tag='SSO', start=876, len=1),
#    Token(form='영화', tag='NNG', start=877, len=2),
#    Token(form='투자자', tag='NNG', start=880, len=3),
#    Token(form="'", tag='SSC', start=883, len=1),
#    Token(form='이선정', tag='NNP', start=885, len=3),
#    Token(form='성원', tag='NNP', start=889, len=2),
#    Token(form='제약', tag='NNG', start=891, len=2),
#    Token(form='대표', tag='NNG', start=894, len=2),
#    Token(form='이사', tag='NNG', start=896, len=2),
#    Token(form='CJ', tag='SL', start=899, len=2),
#    Token(form='ENM', tag='SL', start=902, len=3),
#    Token(form=',', tag='SP', start=905, len=1),
#    Token(form='3', tag='SN', start=907, len=1),
#    Token(form='분기', tag='NNG', start=908, len=2),
#    Token(form='연속', tag='NNG', start=911, len=2),
#    Token(form='흑자', tag='NNG', start=914, len=2),
#    Token(form='..', tag='SF', start=916, len=2),
#    Token(form='티빙', tag='NNP', start=918, len=2),
#    Token(form=',', tag='SP', start=920, len=1),
#    Token(form='넷플릭스', tag='NNP', start=922, len=4),
#    Token(form='턱밑', tag='NNG', start=927, len=2),
#    Token(form='추격', tag='NNG', start=930, len=2),
#    Token(form='‘', tag='SSO', start=933, len=1),
#    Token(form='채식주의자', tag='NNG', start=934, len=5),
#    Token(form='’', tag='SSC', start=939, len=1),
#    Token(form='36', tag='SN', start=941, len=2),
#    Token(form='초', tag='NNG', start=943, len=1),
#    Token(form='요약', tag='NNG', start=945, len=2),
#    Token(form=',', tag='SP', start=947, len=1),
#    Token(form='영화', tag='NNG', start=949, len=2),
#    Token(form='는', tag='JX', start=951, len=1),
#    Token(form='2', tag='SN', start=953, len=1),
#    Token(form='배', tag='NNG', start=954, len=1),
#    Token(form='속', tag='NNG', start=955, len=1),
#    Token(form='…', tag='SE', start=956, len=1),
#    Token(form='짧', tag='VA', start=958, len=1),
#    Token(form='어서', tag='EC', start=959, len=2),
#    Token(form='좋', tag='VA', start=962, len=1),
#    Token(form='다고', tag='EC', start=963, len=2),
#    Token(form='?', tag='SF', start=965, len=1),
#    Token(form="'마리우폴", tag='NNP', start=967, len=5),
#    Token(form='에서', tag='JKB', start=972, len=2),
#    Token(form='의', tag='JKG', start=974, len=1),
#    Token(form='20', tag='SN', start=976, len=2),
#    Token(form='일', tag='NNB', start=978, len=1),
#    Token(form="'", tag='SSO', start=979, len=1),
#    Token(form='수능', tag='NNG', start=981, len=2),
#    Token(form='마치', tag='VV', start=984, len=2),
#    Token(form='ᆫ', tag='ETM', start=985, len=1),
#    Token(form='이', tag='NP', start=987, len=1),
#    Token(form='들', tag='XSN', start=988, len=1),
#    Token(form='이', tag='JKS', start=989, len=1),
#    Token(form='꼭', tag='MAG', start=991, len=1),
#    Token(form='보', tag='VV', start=993, len=1),
#    Token(form='어야', tag='EC', start=993, len=2),
#    Token(form='하', tag='VX', start=996, len=1),
#    Token(form='ᆯ', tag='ETM', start=996, len=1),
#    Token(form='영화', tag='NNG', start=998, len=2),
#    Token(form='넷플릭스', tag='NNP', start=1001, len=4),
#    Token(form='애니메이션', tag='NNG', start=1006, len=5),
#    Token(form="'아케", tag='NNG', start=1012, len=3),
#    Token(form='이', tag='VCP', start=1015, len=1),
#    Token(form='ᆫ', tag='ETM', start=1015, len=1),
#    Token(form="'", tag='SSO', start=1016, len=1),
#    Token(form='시즌', tag='NNG', start=1018, len=2),
#    Token(form='2', tag='SN', start=1020, len=1),
#    Token(form='로', tag='JKB', start=1021, len=1),
#    Token(form='돌아오', tag='VV', start=1023, len=3),
#    Token(form='었', tag='EP', start=1025, len=1),
#    Token(form='다', tag='EF', start=1026, len=1),
#    Token(form='[', tag='SSO', start=1028, len=1),
#    Token(form='위클리', tag='NNP', start=1029, len=3),
#    Token(form='콘', tag='NNG', start=1032, len=1),
#    Token(form=']', tag='SSC', start=1033, len=1),
#    Token(form='오뚜기', tag='NNP', start=1035, len=3),
#    Token(form=',', tag='SP', start=1038, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1040, len=4),
#    Token(form="'", tag='SSC', start=1045, len=1),
#    Token(form='오징어', tag='NNG', start=1046, len=3),
#    Token(form='게임', tag='NNG', start=1049, len=2),
#    Token(form="'", tag='SSO', start=1051, len=1),
#    Token(form='시즌', tag='NNG', start=1052, len=2),
#    Token(form='2', tag='SN', start=1054, len=1),
#    Token(form='와', tag='JC', start=1055, len=1),
#    Token(form='협업', tag='NNG', start=1057, len=2),
#    Token(form='…', tag='SE', start=1059, len=1),
#    Token(form='뿌셔뿌셔', tag='NNP', start=1060, len=4),
#    Token(form='2', tag='SN', start=1065, len=1),
#    Token(form='종', tag='NNG', start=1066, len=1),
#    Token(form='출시', tag='NNG', start=1068, len=2),
#    Token(form='오뚜기', tag='NNP', start=1071, len=3),
#    Token(form=',', tag='SP', start=1074, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1076, len=4),
#    Token(form="'", tag='SSO', start=1081, len=1),
#    Token(form='오징어', tag='NNG', start=1082, len=3),
#    Token(form='게임', tag='NNG', start=1085, len=2),
#    Token(form='시즌', tag='NNG', start=1088, len=2),
#    Token(form='2', tag='SN', start=1090, len=1),
#    Token(form="'", tag='SSC', start=1091, len=1),
#    Token(form='와', tag='JKB', start=1092, len=1),
#    Token(form='만나', tag='VV', start=1094, len=2),
#    Token(form='었', tag='EP', start=1095, len=1),
#    Token(form='다', tag='EF', start=1096, len=1),
#    Token(form='…', tag='SE', start=1097, len=1),
#    Token(form='뿌셔뿌셔', tag='NNP', start=1098, len=4),
#    Token(form='2', tag='SN', start=1103, len=1),
#    Token(form='종', tag='NNG', start=1104, len=1),
#    Token(form='출시', tag='NNG', start=1106, len=2),
#    Token(form='논산', tag='NNP', start=1109, len=2),
#    Token(form='이', tag='JKS', start=1111, len=1),
#    Token(form='뜨', tag='VV', start=1113, len=1),
#    Token(form='ᆫ다', tag='EC', start=1113, len=2),
#    Token(form=',', tag='SP', start=1115, len=1),
#    Token(form='무슨', tag='MM', start=1117, len=2),
#    Token(form='일', tag='NNG', start=1120, len=1),
#    Token(form='?', tag='SF', start=1121, len=1),
#    Token(form='…', tag='SE', start=1122, len=1),
#    Token(form='드라마', tag='NNG', start=1123, len=3),
#    Token(form='·', tag='SP', start=1126, len=1),
#    Token(form='영화', tag='NNG', start=1127, len=2),
#    Token(form='촬영', tag='NNG', start=1130, len=2),
#    Token(form='성지', tag='NNG', start=1133, len=2),
#    Token(form='로', tag='JKB', start=1135, len=1),
#    Token(form='급부상', tag='NNG', start=1137, len=3),
#    Token(form='[', tag='SSO', start=1141, len=1),
#    Token(form='K', tag='SL', start=1142, len=1),
#    Token(form='푸드', tag='NNG', start=1143, len=2),
#    Token(form='신', tag='XPN', start=1146, len=1),
#    Token(form='시장', tag='NNG', start=1147, len=2),
#    Token(form='필리핀', tag='NNP', start=1150, len=3),
#    Token(form='을', tag='JKO', start=1153, len=1),
#    Token(form='가', tag='VV', start=1155, len=1),
#    Token(form='다', tag='EF', start=1156, len=1),
#    Token(form=']', tag='SSC', start=1157, len=1),
#    Token(form='중', tag='NNB', start=1159, len=1),
#    Token(form='독성', tag='NNG', start=1160, len=2),
#    Token(form='자랑', tag='NNG', start=1163, len=2),
#    Token(form='하', tag='XSV', start=1165, len=1),
#    Token(form='는', tag='ETM', start=1166, len=1),
#    Token(form='K', tag='SL', start=1168, len=1),
#    Token(form='이', tag='VCP', start=1169, len=0),
#    Token(form='라면', tag='EC', start=1169, len=2),
#    Token(form='…', tag='SE', start=1171, len=1),
#    Token(form='고', tag='XPN', start=1173, len=1),
#    Token(form='품질', tag='NNG', start=1174, len=2),
#    Token(form='파프리카', tag='NNG', start=1177, len=4),
#    Token(form='도', tag='JX', start=1181, len=1),
#    Token(form='인기', tag='NNG', start=1183, len=2),
#    Token(form='“', tag='SSO', start=1186, len=1),
#    Token(form='다', tag='NNG', start=1187, len=1),
#    Token(form='들', tag='XSN', start=1188, len=1),
#    Token(form='이거', tag='NP', start=1190, len=2),
#    Token(form='보', tag='VV', start=1193, len=1),
#    Token(form='ᆫ다', tag='EF', start=1193, len=2),
#    Token(form='…', tag='SE', start=1195, len=1),
#    Token(form='”', tag='SSC', start=1196, len=1),
#    Token(form='주말', tag='NNG', start=1198, len=2),
#    Token(form='도', tag='JX', start=1200, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1202, len=4),
#    Token(form='1', tag='SN', start=1207, len=1),
#    Token(form='위', tag='NNB', start=1208, len=1),
#    Token(form='먹', tag='VV', start=1210, len=1),
#    Token(form='을', tag='ETM', start=1211, len=1),
#    Token(form='한국', tag='NNP', start=1213, len=2),
#    Token(form='영화', tag='NNG', start=1216, len=2),
#    Token(form='(', tag='SSO', start=1219, len=1),
#    Token(form='+', tag='SW', start=1220, len=1),
#    Token(form='기타', tag='NNG', start=1221, len=2),
#    Token(form='추천작', tag='NNG', start=1224, len=3),
#    Token(form=')', tag='SSC', start=1227, len=1),
#    Token(form='출연진', tag='NNG', start=1229, len=3),
#    Token(form='절반', tag='NNG', start=1233, len=2),
#    Token(form='이', tag='JKS', start=1235, len=1),
#    Token(form='죽', tag='VV', start=1237, len=1),
#    Token(form='는다', tag='EC', start=1238, len=2),
#    Token(form='…', tag='SE', start=1240, len=1),
#    Token(form='충격', tag='NNG', start=1242, len=2),
#    Token(form='스포', tag='NNP', start=1245, len=2),
#    Token(form='뜨', tag='VV', start=1248, len=1),
#    Token(form='ᆫ', tag='ETM', start=1248, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1250, len=4),
#    Token(form='공개', tag='NNG', start=1255, len=2),
#    Token(form='예정', tag='NNG', start=1258, len=2),
#    Token(form='새', tag='MM', start=1261, len=1),
#    Token(form='시리즈', tag='NNG', start=1263, len=3),
#    Token(form='NFL', tag='SL', start=1267, len=3),
#    Token(form='경기', tag='NNG', start=1271, len=2),
#    Token(form='중계', tag='NNG', start=1274, len=2),
#    Token(form='→', tag='SW', start=1276, len=1),
#    Token(form="'", tag='SSO', start=1277, len=1),
#    Token(form='오징어', tag='NNG', start=1278, len=3),
#    Token(form='게임', tag='NNG', start=1282, len=2),
#    Token(form='2', tag='SN', start=1284, len=1),
#    Token(form="'", tag='SSC', start=1285, len=1),
#    Token(form='공개', tag='NNG', start=1287, len=2),
#    Token(form='..', tag='SF', start=1289, len=2),
#    Token(form='넷플릭스', tag='NNP', start=1291, len=4),
#    Token(form='12', tag='SN', start=1296, len=2),
#    Token(form='월', tag='NNB', start=1298, len=1),
#    Token(form="'", tag='SSO', start=1300, len=1),
#    Token(form='슈퍼', tag='NNG', start=1301, len=2),
#    Token(form='골든', tag='NNG', start=1304, len=2),
#    Token(form='데이', tag='NNG', start=1306, len=2),
#    Token(form="'", tag='SSC', start=1308, len=1),
#    Token(form='노리', tag='VV', start=1310, len=2),
#    Token(form='ᆫ다', tag='EF', start=1311, len=2),
#    Token(form='넷플릭스', tag='NNP', start=1314, len=4),
#    Token(form='1', tag='SN', start=1319, len=1),
#    Token(form='위', tag='NNB', start=1320, len=1),
#    Token(form='씹', tag='VV-R', start=1322, len=1),
#    Token(form='어', tag='EC', start=1323, len=1),
#    Token(form='먹', tag='VV', start=1324, len=1),
#    Token(form='는', tag='ETM', start=1325, len=1),
#    Token(form='중', tag='NNB', start=1327, len=1),
#    Token(form='…', tag='SE', start=1328, len=1),
#    Token(form='공개', tag='NNG', start=1329, len=2),
#    Token(form='이틀', tag='NNG', start=1332, len=2),
#    Token(form='만', tag='NNB', start=1335, len=1),
#    Token(form='에', tag='JKB', start=1336, len=1),
#    Token(form='반응', tag='NNG', start=1338, len=2),
#    Token(form='터지', tag='VV', start=1341, len=2),
#    Token(form='ᆫ', tag='ETM', start=1342, len=1),
#    Token(form="'", tag='SSO', start=1344, len=1),
#    Token(form='한국', tag='NNP', start=1345, len=2),
#    Token(form='영화', tag='NNG', start=1348, len=2),
#    Token(form="'", tag='SSO', start=1350, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1352, len=4),
#    Token(form='추천', tag='NNG', start=1357, len=2),
#    Token(form=',', tag='SP', start=1359, len=1),
#    Token(form='11', tag='SN', start=1361, len=2),
#    Token(form='월', tag='NNB', start=1363, len=1),
#    Token(form='첫째', tag='NR', start=1365, len=2),
#    Token(form='주', tag='NNG', start=1368, len=1),
#    Token(form='신작', tag='NNG', start=1370, len=2),
#    Token(form='소식', tag='NNG', start=1372, len=2),
#    Token(form='사랑', tag='NNG', start=1375, len=2),
#    Token(form='빼', tag='VV', start=1378, len=1),
#    Token(form='고', tag='EC', start=1379, len=1),
#    Token(form='결혼', tag='NNG', start=1381, len=2),
#    Token(form='만', tag='JX', start=1383, len=1),
#    Token(form='하', tag='VV', start=1385, len=1),
#    Token(form='어', tag='EC', start=1385, len=1),
#    Token(form='드리', tag='VX', start=1386, len=2),
#    Token(form='ᆸ니다', tag='EC', start=1387, len=3),
#    Token(form='·', tag='SP', start=1390, len=1),
#    Token(form='플랑크톤', tag='NNG', start=1391, len=4),
#    Token(form='의', tag='JKG', start=1395, len=1),
#    Token(form='삶', tag='NNG', start=1397, len=1),
#    Token(form='…', tag='SE', start=1398, len=1),
#    Token(form='이번', tag='NNG', start=1399, len=2),
#    Token(form='주', tag='NNG', start=1402, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1404, len=4),
#    Token(form='‘', tag='SSO', start=1409, len=1),
#    Token(form='지구', tag='NNG', start=1410, len=2),
#    Token(form='를', tag='JKO', start=1412, len=1),
#    Token(form='지키', tag='VV', start=1414, len=2),
#    Token(form='어라', tag='EC', start=1415, len=2),
#    Token(form='’', tag='SSC', start=1417, len=1),
#    Token(form='감독', tag='NNG', start=1419, len=2),
#    Token(form='은', tag='JX', start=1421, len=1),
#    Token(form='왜', tag='MAG', start=1423, len=1),
#    Token(form='“', tag='SSO', start=1425, len=1),
#    Token(form='한국', tag='NNP', start=1426, len=2),
#    Token(form='영화', tag='NNG', start=1429, len=2),
#    Token(form='위태롭', tag='VA-I', start=1432, len=3),
#    Token(form='다', tag='EF', start=1435, len=1),
#    Token(form='”', tag='SSC', start=1436, len=1),
#    Token(form='고', tag='JKQ', start=1437, len=1),
#    Token(form='하', tag='VV', start=1439, len=1),
#    Token(form='었', tag='EP', start=1439, len=1),
#    Token(form='을까', tag='EC', start=1440, len=2),
#    Token(form='부진', tag='NNG', start=1443, len=2),
#    Token(form='하', tag='XSA', start=1445, len=1),
#    Token(form='ᆫ', tag='ETM', start=1445, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1447, len=4),
#    Token(form='시즌', tag='NNG', start=1452, len=2),
#    Token(form='제', tag='XSN', start=1454, len=1),
#    Token(form='들', tag='XSN', start=1455, len=1),
#    Token(form=',', tag='SP', start=1456, len=1),
#    Token(form='"', tag='SS', start=1458, len=1),
#    Token(form='과도기', tag='NNG', start=1459, len=3),
#    Token(form='...', tag='SF', start=1462, len=3),
#    Token(form='시스템', tag='NNG', start=1466, len=3),
#    Token(form='필요', tag='NNG', start=1470, len=2),
#    Token(form='"', tag='SSO', start=1472, len=1),
#    Token(form='갑', tag='NNG', start=1474, len=1),
#    Token(form='질', tag='XSN', start=1475, len=1),
#    Token(form='부터', tag='JX', start=1476, len=2),
#    Token(form='표절', tag='NNG', start=1479, len=2),
#    Token(form='까지', tag='JX', start=1481, len=2),
#    Token(form='…', tag='SE', start=1483, len=1),
#    Token(form='공개', tag='NNG', start=1485, len=2),
#    Token(form='도', tag='JX', start=1487, len=1),
#    Token(form='전', tag='NNG', start=1489, len=1),
#    Token(form='부터', tag='JX', start=1490, len=2),
#    Token(form='온갖', tag='MM', start=1493, len=2),
#    Token(form='논란', tag='NNG', start=1496, len=2),
#    Token(form='휘말리', tag='VV', start=1499, len=3),
#    Token(form='ᆫ', tag='ETM', start=1501, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1503, len=4),
#    Token(form='대작', tag='NNG', start=1508, len=2),
#    Token(form="'", tag='SSO', start=1511, len=1),
#    Token(form='한국', tag='NNP', start=1512, len=2),
#    Token(form='드라마', tag='NNG', start=1515, len=3),
#    Token(form="'", tag='SSC', start=1518, len=1),
#    Token(form='‘', tag='SSO', start=1520, len=1),
#    Token(form='재벌', tag='NNG', start=1521, len=2),
#    Token(form='집', tag='NNG', start=1523, len=1),
#    Token(form='’', tag='SSC', start=1524, len=1),
#    Token(form='비웃', tag='VV-R', start=1526, len=2),
#    Token(form='던', tag='ETM', start=1528, len=1),
#    Token(form='‘', tag='SSO', start=1530, len=1),
#    Token(form='테이크', tag='NNG', start=1531, len=3),
#    Token(form='원', tag='NNG', start=1535, len=1),
#    Token(form='’', tag='SSC', start=1536, len=1),
#    Token(form='실패', tag='NNG', start=1538, len=2),
#    Token(form='…', tag='SE', start=1540, len=1),
#    Token(form='흑백', tag='NNG', start=1541, len=2),
#    Token(form='요리사', tag='NNG', start=1543, len=3),
#    Token(form='PD', tag='SL', start=1547, len=2),
#    Token(form=',', tag='SP', start=1549, len=1),
#    Token(form='그렇', tag='VA-I', start=1551, len=2),
#    Token(form='게', tag='EC', start=1553, len=1),
#    Token(form='‘', tag='SSO', start=1555, len=1),
#    Token(form='진짜', tag='NNG', start=1556, len=2),
#    Token(form='’', tag='SSC', start=1558, len=1),
#    Token(form='를', tag='JKO', start=1559, len=1),
#    Token(form='찾', tag='VV', start=1561, len=1),
#    Token(form='었', tag='EP', start=1562, len=1),
#    Token(form='다', tag='EF', start=1563, len=1),
#    Token(form='[', tag='SSO', start=1565, len=1),
#    Token(form='안혜리', tag='NNP', start=1566, len=3),
#    Token(form='의', tag='JKG', start=1569, len=1),
#    Token(form='인생', tag='NNG', start=1571, len=2),
#    Token(form=']', tag='SSC', start=1573, len=1),
#    Token(form='이', tag='MM', start=1575, len=1),
#    Token(form='번', tag='NNB', start=1576, len=1),
#    Token(form='주', tag='NNB', start=1577, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1579, len=4),
#    Token(form='뭐', tag='IC', start=1584, len=1),
#    Token(form='보', tag='VV', start=1586, len=1),
#    Token(form='지', tag='EF', start=1587, len=1),
#    Token(form='?', tag='SF', start=1588, len=1),
#    Token(form='/', tag='SP', start=1590, len=1),
#    Token(form='〈', tag='SSO', start=1592, len=1),
#    Token(form='Mr.', tag='SL', start=1593, len=3),
#    Token(form='플랑크톤', tag='NNG', start=1597, len=4),
#    Token(form='〉', tag='SSC', start=1601, len=1),
#    Token(form='〈', tag='SSO', start=1603, len=1),
#    Token(form='스포트라이트', tag='NNG', start=1604, len=6),
#    Token(form='는', tag='JX', start=1610, len=1),
#    Token(form='나', tag='NP', start=1612, len=1),
#    Token(form='의', tag='JKG', start=1613, len=1),
#    Token(form='것', tag='NNB', start=1615, len=1),
#    Token(form='〉', tag='SSC', start=1616, len=1),
#    Token(form='등', tag='NNB', start=1618, len=1),
#    Token(form='"', tag='SSC', start=1620, len=1),
#    Token(form='하', tag='XSA', start=1621, len=1),
#    Token(form='게', tag='EC', start=1621, len=1),
#    Token(form='미', tag='XPN', start=1622, len=1),
#    Token(form='폭발', tag='NNG', start=1624, len=2),
#    Token(form='조합', tag='NNG', start=1627, len=2),
#    Token(form='…', tag='SE', start=1629, len=1),
#    Token(form='"', tag='SSO', start=1630, len=1),
#    Token(form='누리', tag='NNG', start=1632, len=2),
#    Token(form='꾼', tag='XSN', start=1634, len=1),
#    Token(form='호평', tag='NNG', start=1636, len=2),
#    Token(form='속', tag='NNG', start=1639, len=1),
#    Token(form='오늘', tag='NNG', start=1641, len=2),
#    Token(form='(', tag='SSO', start=1643, len=1),
#    Token(form='8', tag='SN', start=1644, len=1),
#    Token(form='일', tag='NNB', start=1645, len=1),
#    Token(form=')', tag='SSC', start=1646, len=1),
#    Token(form='공개', tag='NNG', start=1648, len=2),
#    Token(form='앞두', tag='VV', start=1651, len=2),
#    Token(form='ᆫ', tag='ETM', start=1652, len=1),
#    Token(form="'", tag='SSO', start=1654, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1655, len=4),
#    Token(form='드라마', tag='NNG', start=1660, len=3),
#    Token(form="'", tag='SSO', start=1663, len=1),
#    Token(form='압도', tag='NNG', start=1665, len=2),
#    Token(form='적', tag='XSN', start=1667, len=1),
#    Token(form='이', tag='VCP', start=1668, len=1),
#    Token(form='다', tag='EC', start=1669, len=1),
#    Token(form='…', tag='SE', start=1670, len=1),
#    Token(form='전', tag='MM', start=1671, len=1),
#    Token(form='세계', tag='NNG', start=1673, len=2),
#    Token(form='뒤흔', tag='NNG', start=1676, len=2),
#    Token(form='든', tag='JX', start=1678, len=1),
#    Token(form='제작비', tag='NNG', start=1680, len=3),
#    Token(form="'", tag='SSO', start=1684, len=1),
#    Token(form='1000', tag='SN', start=1685, len=4),
#    Token(form="'", tag='SSC', start=1689, len=1),
#    Token(form='억', tag='NR', start=1690, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1692, len=4),
#    Token(form='한국', tag='NNP', start=1697, len=2),
#    Token(form='영화', tag='NNG', start=1700, len=2),
#    Token(form='[', tag='SSO', start=1703, len=1),
#    Token(form='영화', tag='NNG', start=1704, len=2),
#    Token(form='평점', tag='NNG', start=1706, len=2),
#    Token(form=']', tag='SSC', start=1708, len=1),
#    Token(form='기다리', tag='VV', start=1710, len=3),
#    Token(form='ᆫ', tag='ETM', start=1712, len=1),
#    Token(form='보람', tag='NNG', start=1714, len=2),
#    Token(form='이', tag='JKS', start=1716, len=1),
#    Token(form='있', tag='VV', start=1718, len=1),
#    Token(form='다', tag='EF', start=1719, len=1),
#    Token(form='!', tag='SF', start=1720, len=1),
#    Token(form='명작', tag='NNG', start=1722, len=2),
#    Token(form='탄생', tag='NNG', start=1725, len=2),
#    Token(form="'", tag='SSO', start=1728, len=1),
#    Token(form='글래디에이터2', tag='NNG', start=1729, len=7),
#    Token(form="'", tag='SSC', start=1736, len=1),
#    Token(form='[', tag='SSO', start=1738, len=1),
#    Token(form='주말', tag='NNG', start=1739, len=2),
#    Token(form='PICK', tag='SL', start=1742, len=4),
#    Token(form='!', tag='SF', start=1746, len=1),
#    Token(form=']', tag='SSC', start=1747, len=1),
#    Token(form='김태리', tag='NNP', start=1749, len=3),
#    Token(form='·', tag='SP', start=1752, len=1),
#    Token(form='이정재', tag='NNP', start=1753, len=3),
#    Token(form='인기', tag='NNG', start=1757, len=2),
#    Token(form='치솟', tag='VV-R', start=1760, len=2),
#    Token(form='더니', tag='EC', start=1762, len=2),
#    Token(form='…', tag='SE', start=1764, len=1),
#    Token(form='‘', tag='SSO', start=1765, len=1),
#    Token(form='정년', tag='NNP', start=1766, len=2),
#    Token(form='이', tag='JKS', start=1768, len=1),
#    Token(form='’', tag='SSC', start=1769, len=1),
#    Token(form='찐빵', tag='NNG', start=1771, len=2),
#    Token(form='·', tag='SP', start=1773, len=1),
#    Token(form='‘', tag='SSO', start=1774, len=1),
#    Token(form='오징어', tag='NNG', start=1775, len=3),
#    Token(form='게임', tag='NNG', start=1779, len=2),
#    Token(form='2', tag='SN', start=1781, len=1),
#    Token(form='’', tag='SSC', start=1782, len=1),
#    Token(form='뿌셔뿌셔', tag='NNP', start=1784, len=4),
#    Token(form='맛보', tag='VV', start=1789, len=2),
#    Token(form='ᆯ까', tag='EF', start=1790, len=2),
#    Token(form='윤여정', tag='NNP', start=1793, len=3),
#    Token(form=',', tag='SP', start=1796, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1798, len=4),
#    Token(form="'", tag='SSO', start=1803, len=1),
#    Token(form='성나', tag='VV', start=1804, len=2),
#    Token(form='ᆫ', tag='ETM', start=1805, len=1),
#    Token(form='사람', tag='NNG', start=1807, len=2),
#    Token(form='들', tag='XSN', start=1809, len=1),
#    Token(form='ᆯ', tag='ETM', start=1810, len=1),
#    Token(form="'", tag='SSC', start=1811, len=1),
#    Token(form='합류', tag='NNG', start=1813, len=2),
#    Token(form='[', tag='SSO', start=1816, len=1),
#    Token(form='스타', tag='NNG', start=1817, len=2),
#    Token(form='이슈', tag='NNG', start=1819, len=2),
#    Token(form=']', tag='SSC', start=1821, len=1),
#    Token(form='드라마', tag='NNG', start=1823, len=3),
#    Token(form=',', tag='SP', start=1826, len=1),
#    Token(form='영화', tag='NNG', start=1828, len=2),
#    Token(form='흥행', tag='NNG', start=1831, len=2),
#    Token(form='과', tag='JKB', start=1833, len=1),
#    Token(form='함께', tag='MAG', start=1835, len=2),
#    Token(form='논산', tag='NNP', start=1838, len=2),
#    Token(form='이', tag='JKS', start=1840, len=1),
#    Token(form='뜨', tag='VV', start=1842, len=1),
#    Token(form='ᆫ다', tag='EF', start=1842, len=2),
#    Token(form="'", tag='SSO', start=1845, len=1),
#    Token(form='콘텐츠', tag='NNG', start=1846, len=3),
#    Token(form='드라이브', tag='NNG', start=1850, len=4),
#    Token(form="'", tag='SSC', start=1854, len=1),
#    Token(form='건', tag='NNB', start=1856, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1858, len=4),
#    Token(form='다음', tag='NNG', start=1863, len=2),
#    Token(form='스텝', tag='NNG', start=1866, len=2),
#    Token(form='은', tag='JX', start=1868, len=1),
#    Token(form='…', tag='SE', start=1869, len=1),
#    Token(form='1', tag='SN', start=1870, len=1),
#    Token(form='위', tag='NNB', start=1871, len=1),
#    Token(form='자리', tag='NNG', start=1873, len=2),
#    Token(form='굳히', tag='VV', start=1876, len=2),
#    Token(form='나', tag='EC', start=1878, len=1),
#    Token(form='마침내', tag='MAG', start=1880, len=3),
#    Token(form='시작', tag='NNG', start=1884, len=2),
#    Token(form='되', tag='XSV', start=1886, len=1),
#    Token(form='었', tag='EP', start=1886, len=1),
#    Token(form='다', tag='EC', start=1887, len=1),
#    Token(form='…', tag='SE', start=1888, len=1),
#    Token(form='전', tag='MM', start=1889, len=1),
#    Token(form='세계', tag='NNG', start=1891, len=2),
#    Token(form='뒤흔들', tag='VV', start=1894, len=3),
#    Token(form='넷플릭스', tag='NNP', start=1898, len=4),
#    Token(form='시청', tag='NNG', start=1903, len=2),
#    Token(form='률', tag='XSN', start=1905, len=1),
#    Token(form='1', tag='SN', start=1907, len=1),
#    Token(form='위', tag='NNB', start=1908, len=1),
#    Token(form='대작', tag='NNG', start=1910, len=2),
#    Token(form=',', tag='SP', start=1912, len=1),
#    Token(form='벌써', tag='MAG', start=1914, len=2),
#    Token(form='팬', tag='NNG', start=1917, len=1),
#    Token(form='반응', tag='NNG', start=1919, len=2),
#    Token(form='폭발', tag='NNG', start=1922, len=2),
#    Token(form="'", tag='SSO', start=1925, len=1),
#    Token(form='청설', tag='NNP', start=1926, len=2),
#    Token(form="'", tag='SSC', start=1928, len=1),
#    Token(form='→', tag='SW', start=1929, len=1),
#    Token(form="'", tag='SSO', start=1930, len=1),
#    Token(form='말', tag='NNG', start=1931, len=1),
#    Token(form='하', tag='XSV', start=1932, len=1),
#    Token(form='ᆯ', tag='ETM', start=1932, len=1),
#    Token(form='수', tag='NNB', start=1934, len=1),
#    Token(form='없', tag='VA', start=1936, len=1),
#    Token(form='는', tag='ETM', start=1937, len=1),
#    Token(form='비밀', tag='NNG', start=1939, len=2),
#    Token(form="'", tag='SSC', start=1941, len=1),
#    Token(form=',', tag='SP', start=1942, len=1),
#    Token(form='한국', tag='NNP', start=1944, len=2),
#    Token(form='버전', tag='NNG', start=1947, len=2),
#    Token(form='으로', tag='JKB', start=1949, len=2),
#    Token(form='리메이크', tag='NNG', start=1952, len=4),
#    Token(form='되', tag='XSV', start=1956, len=1),
#    Token(form='ᆫ', tag='ETM', start=1956, len=1),
#    Token(form='대만', tag='NNP', start=1958, len=2),
#    Token(form='청춘', tag='NNG', start=1961, len=2),
#    Token(form='영화', tag='NNG', start=1964, len=2),
#    Token(form='[', tag='SSO', start=1967, len=1),
#    Token(form='씨네', tag='NNP', start=1968, len=2),
#    Token(form='T', tag='SL', start=1970, len=1),
#    Token(form=']', tag='SSC', start=1971, len=1),
#    Token(form='웹툰', tag='NNP', start=1973, len=2),
#    Token(form='`', tag='SW', start=1976, len=1),
#    Token(form='알', tag='VV', start=1977, len=1),
#    Token(form='고', tag='EC', start=1978, len=1),
#    Token(form='있', tag='VX', start=1980, len=1),
#    Token(form='지만', tag='EC', start=1981, len=2),
#    Token(form='`', tag='SW', start=1983, len=1),
#    Token(form='일본', tag='NNP', start=1985, len=2),
#    Token(form='리메이크', tag='NNG', start=1988, len=4),
#    Token(form='작', tag='NNG', start=1992, len=1),
#    Token(form='12', tag='SN', start=1994, len=2),
#    Token(form='월', tag='NNB', start=1996, len=1),
#    Token(form='넷플릭스', tag='NNP', start=1998, len=4),
#    Token(form='에서', tag='JKB', start=2002, len=2),
#    Token(form='전', tag='MM', start=2005, len=1),
#    Token(form='세계', tag='NNG', start=2007, len=2),
#    Token(form='공개', tag='NNG', start=2010, len=2),
#    Token(form='공개', tag='NNG', start=2013, len=2),
#    Token(form='직후', tag='NNG', start=2016, len=2),
#    Token(form="'", tag='SSO', start=2019, len=1),
#    Token(form='이친자', tag='NNG', start=2020, len=3),
#    Token(form="'", tag='SSC', start=2023, len=1),
#    Token(form='와', tag='JC', start=2024, len=1),
#    Token(form='경쟁', tag='NNG', start=2026, len=2),
#    Token(form=',', tag='SP', start=2028, len=1),
#    Token(form='넷플릭스', tag='NNP', start=2030, len=4),
#    Token(form='상위', tag='NNG', start=2035, len=2),
#    Token(form='권', tag='XSN', start=2037, len=1),
#    Token(form='랭크', tag='NNG', start=2039, len=2),
#    Token(form='…', tag='SE', start=2041, len=1),
#    Token(form='반응', tag='NNG', start=2043, len=2),
#    Token(form='완전', tag='MAG', start=2046, len=2),
#    Token(form='터지', tag='VV', start=2049, len=2),
#    Token(form='었', tag='EP', start=2050, len=1),
#    Token(form='다는', tag='ETM', start=2051, len=2),
#    Token(form='한국', tag='NNP', start=2054, len=2),
#    Token(form='드라마', tag='NNG', start=2057, len=3),
#    Token(form='(', tag='SSO', start=2061, len=1),
#    Token(form='+', tag='SW', start=2062, len=1),
#    Token(form='환승', tag='NNG', start=2063, len=2),
#    Token(form='연애', tag='NNG', start=2065, len=2),
#    Token(form='재질', tag='NNG', start=2068, len=2),
#    Token(form=')', tag='SSC', start=2070, len=1),
#    Token(form='고민', tag='NNG', start=2072, len=2),
#    Token(form='시', tag='NNB', start=2074, len=1),
#    Token(form=',', tag='SP', start=2075, len=1),
#    Token(form='성', tag='NNG', start=2077, len=1),
#    Token(form='덕', tag='NNG', start=2078, len=1),
#    Token(form='되', tag='XSV', start=2079, len=1),
#    Token(form='었', tag='EP', start=2079, len=1),
#    Token(form='다', tag='EC', start=2080, len=1),
#    Token(form='…', tag='SE', start=2081, len=1),
#    Token(form='차기작', tag='NNG', start=2082, len=3),
#    Token(form='은', tag='JX', start=2085, len=1),
#    Token(form="'", tag='SSO', start=2087, len=1),
#    Token(form='우리', tag='NP', start=2088, len=2),
#    Token(form='들', tag='XSN', start=2090, len=1),
#    Token(form="'", tag='SSC', start=2091, len=1),
#    Token(form='윤가은', tag='NNP', start=2093, len=3),
#    ...],
#   -46113.44921875)]

# %%
n = []
result = kiwi.analyze(input_wc)
for token in result[0][0]:
    if token.tag in ['NNG', 'NNP']:
        n.append(token.form)
        
n_count = Counter(n)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc = WordCloud(
    font_path="C:\\Users\\manun\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumGothic.ttf",
    width=950,
    height=720
)
cloud = wc.generate(input_wc)
plt.figure(figsize=(10, 8))
plt.imshow(cloud, interpolation='bilinear')
plt.axis('off')
plt.show()
